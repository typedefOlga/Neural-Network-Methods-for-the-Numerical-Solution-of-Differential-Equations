# %%
# !pip install deepxde
# Out:
# Requirement already satisfied: deepxde in /usr/local/lib/python3.12/dist-packages (1.15.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from deepxde) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from deepxde) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from deepxde) (1.6.1)
# Requirement already satisfied: scikit-optimize>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from deepxde) (0.10.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from deepxde) (1.16.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize>=0.10.2->deepxde) (1.5.3)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize>=0.10.2->deepxde) (26.2.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize>=0.10.2->deepxde) (26.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->deepxde) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deepxde) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deepxde) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deepxde) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deepxde) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deepxde) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deepxde) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deepxde) (2.9.0.post0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from pyaml>=16.9->scikit-optimize>=0.10.2->deepxde) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.17.0)

# %%
from abc import update_abstractmethods
import deepxde as dde
import numpy as np
from deepxde.backend import tf
import matplotlib.pyplot as plt
# Out:
# Using backend: tensorflow
# Other supported backends: tensorflow.compat.v1, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# Enable just-in-time compilation with XLA.

# %%
pi = np.pi
geom = dde.geometry.Rectangle(xmin=[0, -pi], xmax=[pi, pi])
timedomain = dde.geometry.TimeDomain(0, 1)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

# %%
lam_init = -5
lam = dde.Variable(float(lam_init))

def pde(x, u):
  u_t = dde.grad.jacobian(u, x, i=0, j=2)
  u_xx = dde.grad.hessian(u, x, i=0, j=0)
  u_yy = dde.grad.hessian(u, x, i=1, j=1)
  y = x[:, 1:2]
  t = x[:, 2:3]
  return u_t - (3/2)*(u_xx + u_yy) - \
    lam * tf.exp(-21*t/10) * tf.cos(3*y/5) \
    - 138 * tf.exp(-21*t/10) * tf.sin(9*x[:, 0:1]/5) / 25

# %%
def initial_cond(x, on_initial):
  return on_initial and np.isclose(x[2], 0)

def fic(x):
  return 2 * tf.sin(9*x[:, 0:1]/5) + \
    11 * tf.cos(3*x[:, 1:2]/5) / 5 + 7/5

ic = dde.icbc.IC(geomtime, fic, initial_cond)

def boundary_left(x, on_boundary):
    return on_boundary and np.isclose(x[0], 0)
def boundary_right(x, on_boundary):
    return on_boundary and np.isclose(x[0], pi)
def boundary_bottom(x, on_boundary):
    return on_boundary and np.isclose(x[1], -pi)
def boundary_top(x, on_boundary):
    return on_boundary and np.isclose(x[1], pi)

def fleft(x):
  return - 18 * tf.exp(-21*x[:, 2:3]/10) /5
def fright(x):
  exp = tf.exp(-21*x[:, 2:3]/10)
  return 9*exp/10 + 9*tf.cast(tf.sqrt(5.0), tf.float32)*exp/10
def ftopbottom(x):
  exp = tf.exp(-21*x[:, 2:3]/10)
  return 7/5 + 2*exp*tf.sin(9*x[:, 0:1]/5) - \
    11*tf.cast(tf.sqrt(5.0), tf.float32)*exp/20 + 11*exp/20


bc_left = dde.icbc.NeumannBC(geomtime, fleft, boundary_left)
bc_right = dde.icbc.NeumannBC(geomtime, fright, boundary_right)
bc_bottom = dde.icbc.DirichletBC(geomtime, ftopbottom, boundary_bottom)
bc_top = dde.icbc.DirichletBC(geomtime, ftopbottom, boundary_top)

# %%
file_data = np.load('var-05.npz')
xyt = file_data['xyt']
u = file_data['u']
bc_points = dde.icbc.PointSetBC(xyt, u)

data = dde.data.TimePDE(
    geomtime,
    pde,
    [ic, bc_left, bc_right, bc_top, bc_bottom, bc_points],
    num_domain=1000,
    num_boundary=500,
    num_initial=700,
    anchors=xyt,
    train_distribution="uniform",
    num_test=1000,
)
# Out:
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.

# %%
layer_size = [3] + [32] * 4 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)
model = dde.Model(data, net)

# %%
variable_cb = dde.callbacks.VariableValue(lam, period=1000)
resampler_cb = dde.callbacks.PDEPointResampler(period=1000)
lam_history = []
class LambdaHistory(dde.callbacks.Callback):
  def on_epoch_end(self):
      val = lam.value() if callable(lam.value) else lam.value
      if hasattr(val, 'numpy'):
          val = val.numpy()
      lam_history.append(float(val))
history_cb = LambdaHistory()

model.compile("adam", lr=0.001, external_trainable_variables=lam)
losshistory, train_state = model.train(iterations=3000, callbacks=[variable_cb, resampler_cb, history_cb])

model.compile("adam", lr=1e-4, external_trainable_variables=lam)
losshistory, train_state = model.train(iterations=20000, callbacks=[variable_cb, resampler_cb, history_cb])

model.compile("adam", lr=1e-5, external_trainable_variables=lam)
losshistory, train_state = model.train(iterations=20000, callbacks=[variable_cb, resampler_cb, history_cb])

model.compile("adam", lr=1e-6, external_trainable_variables=lam)
losshistory, train_state = model.train(iterations=20000, callbacks=[variable_cb, resampler_cb, history_cb])

dde.saveplot(losshistory, train_state, issave=True, isplot=True)

plt.figure()
plt.plot(lam_history)
plt.xlabel('Iteration')
plt.ylabel('lam')
plt.title(f'Изменение lam (начальное приближение {lam_init})')
plt.grid(True)
plt.savefig(f'lambda_history.png')
plt.show()

val = lam.value() if callable(lam.value) else lam.value
if hasattr(val, 'numpy'):
    val = val.numpy()
final_lam = float(val)
print(f"Финальное lam для запуска с начальным {lam_init}: {final_lam}")
# Out:
# Compiling model...
# 'compile' took 0.010459 s
#
# Training model...
#
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Step      Train loss                                                                Test loss                                                                 Test metric
# 0         [8.40e-01, 9.65e+00, 1.99e+00, 1.14e+00, 3.32e+00, 8.97e-01, 2.54e+00]    [4.83e+00, 9.65e+00, 1.99e+00, 1.14e+00, 3.32e+00, 8.97e-01, 2.54e+00]    []
# 0 [-5.00e+00]
# 1000      [8.04e-03, 1.08e-03, 9.40e-04, 1.88e-02, 5.19e-04, 4.39e-04, 6.41e-04]    [1.46e-01, 1.08e-03, 9.40e-04, 1.88e-02, 5.19e-04, 4.39e-04, 6.41e-04]    []
# 1000 [-4.67e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 2000      [3.27e-03, 9.04e-04, 2.71e-04, 1.51e-02, 4.91e-04, 3.85e-04, 3.69e-04]    [9.75e-02, 9.04e-04, 2.71e-04, 1.51e-02, 4.91e-04, 3.85e-04, 3.69e-04]    []
# 2000 [-4.51e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 3000      [2.29e-03, 8.00e-04, 1.71e-04, 1.23e-02, 4.00e-04, 3.19e-04, 2.19e-04]    [6.94e-02, 8.00e-04, 1.71e-04, 1.23e-02, 4.00e-04, 3.19e-04, 2.19e-04]    []
# 3000 [-4.31e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
#
# Best model at step 3000:
#   train loss: 1.65e-02
#   test loss: 8.35e-02
#   test metric: []
#
# 'train' took 92.439341 s
#
# Compiling model...
# 'compile' took 0.005311 s
#
# Training model...
#
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Step      Train loss                                                                Test loss                                                                 Test metric
# 3000      [2.29e-03, 8.00e-04, 1.71e-04, 1.23e-02, 4.00e-04, 3.19e-04, 2.19e-04]    [6.94e-02, 8.00e-04, 1.71e-04, 1.23e-02, 4.00e-04, 3.19e-04, 2.19e-04]    []
# 3000 [-4.31e+00]
# 4000      [2.14e-03, 6.97e-04, 1.49e-04, 1.05e-02, 3.84e-04, 3.29e-04, 1.60e-04]    [6.00e-02, 6.97e-04, 1.49e-04, 1.05e-02, 3.84e-04, 3.29e-04, 1.60e-04]    []
# 4000 [-4.21e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 5000      [2.12e-03, 5.95e-04, 1.21e-04, 8.21e-03, 3.94e-04, 3.71e-04, 9.16e-05]    [5.08e-02, 5.95e-04, 1.21e-04, 8.21e-03, 3.94e-04, 3.71e-04, 9.16e-05]    []
# 5000 [-4.12e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 6000      [2.12e-03, 6.14e-04, 1.15e-04, 6.73e-03, 3.80e-04, 3.82e-04, 1.10e-04]    [4.47e-02, 6.14e-04, 1.15e-04, 6.73e-03, 3.80e-04, 3.82e-04, 1.10e-04]    []
# 6000 [-4.03e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 7000      [2.08e-03, 4.62e-04, 1.07e-04, 5.68e-03, 4.14e-04, 4.21e-04, 5.73e-05]    [3.98e-02, 4.62e-04, 1.07e-04, 5.68e-03, 4.14e-04, 4.21e-04, 5.73e-05]    []
# 7000 [-3.94e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 8000      [2.03e-03, 4.26e-04, 1.08e-04, 4.76e-03, 4.25e-04, 4.28e-04, 5.10e-05]    [3.65e-02, 4.26e-04, 1.08e-04, 4.76e-03, 4.25e-04, 4.28e-04, 5.10e-05]    []
# 8000 [-3.85e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 9000      [1.95e-03, 4.08e-04, 1.09e-04, 3.99e-03, 4.36e-04, 4.21e-04, 4.53e-05]    [3.43e-02, 4.08e-04, 1.09e-04, 3.99e-03, 4.36e-04, 4.21e-04, 4.53e-05]    []
# 9000 [-3.77e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 10000     [1.85e-03, 4.04e-04, 1.05e-04, 3.44e-03, 5.08e-04, 4.76e-04, 3.07e-05]    [3.28e-02, 4.04e-04, 1.05e-04, 3.44e-03, 5.08e-04, 4.76e-04, 3.07e-05]    []
# 10000 [-3.69e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 11000     [1.76e-03, 3.88e-04, 1.04e-04, 2.97e-03, 4.00e-04, 4.07e-04, 3.74e-05]    [3.22e-02, 3.88e-04, 1.04e-04, 2.97e-03, 4.00e-04, 4.07e-04, 3.74e-05]    []
# 11000 [-3.61e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 12000     [1.67e-03, 3.76e-04, 1.01e-04, 2.65e-03, 3.71e-04, 3.91e-04, 3.56e-05]    [3.18e-02, 3.76e-04, 1.01e-04, 2.65e-03, 3.71e-04, 3.91e-04, 3.56e-05]    []
# 12000 [-3.55e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 13000     [1.59e-03, 3.57e-04, 1.00e-04, 2.39e-03, 3.44e-04, 3.71e-04, 3.50e-05]    [3.14e-02, 3.57e-04, 1.00e-04, 2.39e-03, 3.44e-04, 3.71e-04, 3.50e-05]    []
# 13000 [-3.49e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 14000     [1.50e-03, 3.39e-04, 9.98e-05, 2.18e-03, 3.19e-04, 3.46e-04, 3.64e-05]    [3.04e-02, 3.39e-04, 9.98e-05, 2.18e-03, 3.19e-04, 3.46e-04, 3.64e-05]    []
# 14000 [-3.44e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 15000     [1.41e-03, 3.17e-04, 9.97e-05, 2.00e-03, 2.99e-04, 3.19e-04, 3.78e-05]    [2.86e-02, 3.17e-04, 9.97e-05, 2.00e-03, 2.99e-04, 3.19e-04, 3.78e-05]    []
# 15000 [-3.40e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 16000     [1.31e-03, 2.90e-04, 9.86e-05, 1.84e-03, 2.81e-04, 2.95e-04, 3.89e-05]    [2.61e-02, 2.90e-04, 9.86e-05, 1.84e-03, 2.81e-04, 2.95e-04, 3.89e-05]    []
# 16000 [-3.39e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 17000     [1.23e-03, 2.64e-04, 9.60e-05, 1.70e-03, 2.67e-04, 2.72e-04, 4.01e-05]    [2.35e-02, 2.64e-04, 9.60e-05, 1.70e-03, 2.67e-04, 2.72e-04, 4.01e-05]    []
# 17000 [-3.38e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 18000     [1.15e-03, 2.39e-04, 9.23e-05, 1.59e-03, 2.56e-04, 2.53e-04, 4.11e-05]    [2.09e-02, 2.39e-04, 9.23e-05, 1.59e-03, 2.56e-04, 2.53e-04, 4.11e-05]    []
# 18000 [-3.38e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 19000     [1.08e-03, 2.18e-04, 8.79e-05, 1.48e-03, 2.47e-04, 2.37e-04, 4.27e-05]    [1.86e-02, 2.18e-04, 8.79e-05, 1.48e-03, 2.47e-04, 2.37e-04, 4.27e-05]    []
# 19000 [-3.38e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 20000     [1.01e-03, 1.93e-04, 8.33e-05, 1.40e-03, 2.43e-04, 2.28e-04, 4.23e-05]    [1.67e-02, 1.93e-04, 8.33e-05, 1.40e-03, 2.43e-04, 2.28e-04, 4.23e-05]    []
# 20000 [-3.38e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 21000     [9.60e-04, 1.74e-04, 7.89e-05, 1.33e-03, 2.39e-04, 2.20e-04, 4.27e-05]    [1.53e-02, 1.74e-04, 7.89e-05, 1.33e-03, 2.39e-04, 2.20e-04, 4.27e-05]    []
# 21000 [-3.38e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 22000     [9.13e-04, 1.58e-04, 7.50e-05, 1.26e-03, 2.36e-04, 2.14e-04, 4.32e-05]    [1.42e-02, 1.58e-04, 7.50e-05, 1.26e-03, 2.36e-04, 2.14e-04, 4.32e-05]    []
# 22000 [-3.38e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 23000     [8.71e-04, 1.40e-04, 7.16e-05, 1.21e-03, 2.36e-04, 2.13e-04, 4.15e-05]    [1.35e-02, 1.40e-04, 7.16e-05, 1.21e-03, 2.36e-04, 2.13e-04, 4.15e-05]    []
# 23000 [-3.37e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
#
# Best model at step 23000:
#   train loss: 2.78e-03
#   test loss: 1.54e-02
#   test metric: []
#
# 'train' took 520.147613 s
#
# Compiling model...
# 'compile' took 0.004837 s
#
# Training model...
#
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Step      Train loss                                                                Test loss                                                                 Test metric
# 23000     [8.71e-04, 1.40e-04, 7.16e-05, 1.21e-03, 2.36e-04, 2.13e-04, 4.15e-05]    [1.35e-02, 1.40e-04, 7.16e-05, 1.21e-03, 2.36e-04, 2.13e-04, 4.15e-05]    []
# 23000 [-3.37e+00]
# 24000     [8.58e-04, 1.39e-04, 7.10e-05, 1.19e-03, 2.33e-04, 2.10e-04, 4.34e-05]    [1.34e-02, 1.39e-04, 7.10e-05, 1.19e-03, 2.33e-04, 2.10e-04, 4.34e-05]    []
# 24000 [-3.37e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 25000     [8.32e-04, 1.33e-04, 6.93e-05, 1.15e-03, 2.32e-04, 2.08e-04, 4.36e-05]    [1.31e-02, 1.33e-04, 6.93e-05, 1.15e-03, 2.32e-04, 2.08e-04, 4.36e-05]    []
# 25000 [-3.37e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 26000     [8.05e-04, 1.26e-04, 6.73e-05, 1.11e-03, 2.31e-04, 2.07e-04, 4.33e-05]    [1.28e-02, 1.26e-04, 6.73e-05, 1.11e-03, 2.31e-04, 2.07e-04, 4.33e-05]    []
# 26000 [-3.37e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 27000     [7.81e-04, 1.21e-04, 6.56e-05, 1.08e-03, 2.29e-04, 2.05e-04, 4.35e-05]    [1.26e-02, 1.21e-04, 6.56e-05, 1.08e-03, 2.29e-04, 2.05e-04, 4.35e-05]    []
# 27000 [-3.37e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 28000     [7.59e-04, 1.16e-04, 6.40e-05, 1.04e-03, 2.28e-04, 2.03e-04, 4.34e-05]    [1.24e-02, 1.16e-04, 6.40e-05, 1.04e-03, 2.28e-04, 2.03e-04, 4.34e-05]    []
# 28000 [-3.36e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 29000     [7.39e-04, 1.12e-04, 6.25e-05, 1.01e-03, 2.26e-04, 2.02e-04, 4.34e-05]    [1.22e-02, 1.12e-04, 6.25e-05, 1.01e-03, 2.26e-04, 2.02e-04, 4.34e-05]    []
# 29000 [-3.36e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 30000     [7.20e-04, 1.08e-04, 6.12e-05, 9.81e-04, 2.25e-04, 2.00e-04, 4.32e-05]    [1.21e-02, 1.08e-04, 6.12e-05, 9.81e-04, 2.25e-04, 2.00e-04, 4.32e-05]    []
# 30000 [-3.36e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 31000     [7.02e-04, 1.05e-04, 6.00e-05, 9.51e-04, 2.24e-04, 1.99e-04, 4.31e-05]    [1.19e-02, 1.05e-04, 6.00e-05, 9.51e-04, 2.24e-04, 1.99e-04, 4.31e-05]    []
# 31000 [-3.36e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 32000     [6.84e-04, 1.03e-04, 5.90e-05, 9.23e-04, 2.22e-04, 1.97e-04, 4.30e-05]    [1.18e-02, 1.03e-04, 5.90e-05, 9.23e-04, 2.22e-04, 1.97e-04, 4.30e-05]    []
# 32000 [-3.36e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 33000     [6.68e-04, 9.78e-05, 5.79e-05, 8.99e-04, 2.23e-04, 1.98e-04, 4.11e-05]    [1.17e-02, 9.78e-05, 5.79e-05, 8.99e-04, 2.23e-04, 1.98e-04, 4.11e-05]    []
# 33000 [-3.36e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 34000     [6.51e-04, 9.82e-05, 5.71e-05, 8.72e-04, 2.19e-04, 1.95e-04, 4.25e-05]    [1.16e-02, 9.82e-05, 5.71e-05, 8.72e-04, 2.19e-04, 1.95e-04, 4.25e-05]    []
# 34000 [-3.36e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 35000     [6.35e-04, 9.69e-05, 5.63e-05, 8.48e-04, 2.17e-04, 1.93e-04, 4.23e-05]    [1.15e-02, 9.69e-05, 5.63e-05, 8.48e-04, 2.17e-04, 1.93e-04, 4.23e-05]    []
# 35000 [-3.36e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 36000     [6.20e-04, 9.53e-05, 5.55e-05, 8.26e-04, 2.15e-04, 1.92e-04, 4.20e-05]    [1.14e-02, 9.53e-05, 5.55e-05, 8.26e-04, 2.15e-04, 1.92e-04, 4.20e-05]    []
# 36000 [-3.35e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 37000     [6.05e-04, 9.61e-05, 5.48e-05, 8.03e-04, 2.12e-04, 1.89e-04, 4.27e-05]    [1.12e-02, 9.61e-05, 5.48e-05, 8.03e-04, 2.12e-04, 1.89e-04, 4.27e-05]    []
# 37000 [-3.35e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 38000     [5.91e-04, 9.26e-05, 5.40e-05, 7.84e-04, 2.11e-04, 1.89e-04, 4.11e-05]    [1.11e-02, 9.26e-05, 5.40e-05, 7.84e-04, 2.11e-04, 1.89e-04, 4.11e-05]    []
# 38000 [-3.35e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 39000     [5.77e-04, 9.15e-05, 5.33e-05, 7.65e-04, 2.09e-04, 1.87e-04, 4.06e-05]    [1.10e-02, 9.15e-05, 5.33e-05, 7.65e-04, 2.09e-04, 1.87e-04, 4.06e-05]    []
# 39000 [-3.35e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 40000     [5.64e-04, 9.04e-05, 5.25e-05, 7.47e-04, 2.07e-04, 1.86e-04, 4.02e-05]    [1.10e-02, 9.04e-05, 5.25e-05, 7.47e-04, 2.07e-04, 1.86e-04, 4.02e-05]    []
# 40000 [-3.35e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 41000     [5.51e-04, 8.82e-05, 5.17e-05, 7.30e-04, 2.06e-04, 1.86e-04, 3.88e-05]    [1.09e-02, 8.82e-05, 5.17e-05, 7.30e-04, 2.06e-04, 1.86e-04, 3.88e-05]    []
# 41000 [-3.35e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 42000     [5.40e-04, 8.82e-05, 5.10e-05, 7.13e-04, 2.03e-04, 1.84e-04, 3.90e-05]    [1.08e-02, 8.82e-05, 5.10e-05, 7.13e-04, 2.03e-04, 1.84e-04, 3.90e-05]    []
# 42000 [-3.35e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 43000     [5.29e-04, 8.73e-05, 5.03e-05, 6.97e-04, 2.01e-04, 1.82e-04, 3.86e-05]    [1.07e-02, 8.73e-05, 5.03e-05, 6.97e-04, 2.01e-04, 1.82e-04, 3.86e-05]    []
# 43000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
#
# Best model at step 43000:
#   train loss: 1.79e-03
#   test loss: 1.20e-02
#   test metric: []
#
# 'train' took 526.021954 s
#
# Compiling model...
# 'compile' took 0.004796 s
#
# Training model...
#
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Warning: Rectangle boundary_normal called on vertices. You may use PDE(..., exclusions=...) to exclude the vertices.
# Step      Train loss                                                                Test loss                                                                 Test metric
# 43000     [5.29e-04, 8.73e-05, 5.03e-05, 6.97e-04, 2.01e-04, 1.82e-04, 3.86e-05]    [1.07e-02, 8.73e-05, 5.03e-05, 6.97e-04, 2.01e-04, 1.82e-04, 3.86e-05]    []
# 43000 [-3.34e+00]
# 44000     [5.26e-04, 8.71e-05, 5.00e-05, 6.93e-04, 2.01e-04, 1.82e-04, 3.85e-05]    [1.07e-02, 8.71e-05, 5.00e-05, 6.93e-04, 2.01e-04, 1.82e-04, 3.85e-05]    []
# 44000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 45000     [5.22e-04, 8.67e-05, 4.95e-05, 6.87e-04, 2.00e-04, 1.81e-04, 3.81e-05]    [1.06e-02, 8.67e-05, 4.95e-05, 6.87e-04, 2.00e-04, 1.81e-04, 3.81e-05]    []
# 45000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 46000     [5.17e-04, 8.62e-05, 4.90e-05, 6.80e-04, 1.99e-04, 1.80e-04, 3.77e-05]    [1.06e-02, 8.62e-05, 4.90e-05, 6.80e-04, 1.99e-04, 1.80e-04, 3.77e-05]    []
# 46000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 47000     [5.13e-04, 8.60e-05, 4.86e-05, 6.74e-04, 1.98e-04, 1.80e-04, 3.75e-05]    [1.05e-02, 8.60e-05, 4.86e-05, 6.74e-04, 1.98e-04, 1.80e-04, 3.75e-05]    []
# 47000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 48000     [5.08e-04, 8.54e-05, 4.82e-05, 6.68e-04, 1.97e-04, 1.79e-04, 3.71e-05]    [1.05e-02, 8.54e-05, 4.82e-05, 6.68e-04, 1.97e-04, 1.79e-04, 3.71e-05]    []
# 48000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 49000     [5.04e-04, 8.52e-05, 4.78e-05, 6.62e-04, 1.96e-04, 1.79e-04, 3.69e-05]    [1.04e-02, 8.52e-05, 4.78e-05, 6.62e-04, 1.96e-04, 1.79e-04, 3.69e-05]    []
# 49000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 50000     [5.00e-04, 8.48e-05, 4.74e-05, 6.56e-04, 1.96e-04, 1.78e-04, 3.67e-05]    [1.04e-02, 8.48e-05, 4.74e-05, 6.56e-04, 1.96e-04, 1.78e-04, 3.67e-05]    []
# 50000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 51000     [4.95e-04, 8.45e-05, 4.71e-05, 6.50e-04, 1.95e-04, 1.77e-04, 3.65e-05]    [1.03e-02, 8.45e-05, 4.71e-05, 6.50e-04, 1.95e-04, 1.77e-04, 3.65e-05]    []
# 51000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 52000     [4.91e-04, 8.41e-05, 4.68e-05, 6.44e-04, 1.94e-04, 1.77e-04, 3.63e-05]    [1.03e-02, 8.41e-05, 4.68e-05, 6.44e-04, 1.94e-04, 1.77e-04, 3.63e-05]    []
# 52000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 53000     [4.87e-04, 8.36e-05, 4.64e-05, 6.39e-04, 1.93e-04, 1.77e-04, 3.60e-05]    [1.02e-02, 8.36e-05, 4.64e-05, 6.39e-04, 1.93e-04, 1.77e-04, 3.60e-05]    []
# 53000 [-3.34e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 54000     [4.83e-04, 8.32e-05, 4.61e-05, 6.33e-04, 1.93e-04, 1.76e-04, 3.57e-05]    [1.02e-02, 8.32e-05, 4.61e-05, 6.33e-04, 1.93e-04, 1.76e-04, 3.57e-05]    []
# 54000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 55000     [4.79e-04, 8.31e-05, 4.58e-05, 6.27e-04, 1.92e-04, 1.76e-04, 3.57e-05]    [1.02e-02, 8.31e-05, 4.58e-05, 6.27e-04, 1.92e-04, 1.76e-04, 3.57e-05]    []
# 55000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 56000     [4.76e-04, 8.26e-05, 4.55e-05, 6.22e-04, 1.91e-04, 1.75e-04, 3.55e-05]    [1.01e-02, 8.26e-05, 4.55e-05, 6.22e-04, 1.91e-04, 1.75e-04, 3.55e-05]    []
# 56000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 57000     [4.72e-04, 8.23e-05, 4.52e-05, 6.17e-04, 1.90e-04, 1.75e-04, 3.54e-05]    [1.01e-02, 8.23e-05, 4.52e-05, 6.17e-04, 1.90e-04, 1.75e-04, 3.54e-05]    []
# 57000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 58000     [4.68e-04, 8.20e-05, 4.50e-05, 6.11e-04, 1.90e-04, 1.74e-04, 3.52e-05]    [1.00e-02, 8.20e-05, 4.50e-05, 6.11e-04, 1.90e-04, 1.74e-04, 3.52e-05]    []
# 58000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 59000     [4.65e-04, 8.16e-05, 4.47e-05, 6.06e-04, 1.89e-04, 1.74e-04, 3.51e-05]    [9.99e-03, 8.16e-05, 4.47e-05, 6.06e-04, 1.89e-04, 1.74e-04, 3.51e-05]    []
# 59000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 60000     [4.61e-04, 8.13e-05, 4.45e-05, 6.00e-04, 1.88e-04, 1.73e-04, 3.50e-05]    [9.95e-03, 8.13e-05, 4.45e-05, 6.00e-04, 1.88e-04, 1.73e-04, 3.50e-05]    []
# 60000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 61000     [4.58e-04, 8.09e-05, 4.42e-05, 5.95e-04, 1.87e-04, 1.73e-04, 3.48e-05]    [9.90e-03, 8.09e-05, 4.42e-05, 5.95e-04, 1.87e-04, 1.73e-04, 3.48e-05]    []
# 61000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 62000     [4.54e-04, 8.05e-05, 4.40e-05, 5.90e-04, 1.87e-04, 1.73e-04, 3.47e-05]    [9.86e-03, 8.05e-05, 4.40e-05, 5.90e-04, 1.87e-04, 1.73e-04, 3.47e-05]    []
# 62000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
# 63000     [4.51e-04, 8.02e-05, 4.37e-05, 5.85e-04, 1.86e-04, 1.72e-04, 3.46e-05]    [9.82e-03, 8.02e-05, 4.37e-05, 5.85e-04, 1.86e-04, 1.72e-04, 3.46e-05]    []
# 63000 [-3.33e+00]
# Warning: 141 points required, but 153 points sampled.
# Warning: 1000 points required, but 1224 points sampled.
# Warning: 140 points required, but 142 points sampled.
# Warning: 500 points required, but 568 points sampled.
# Warning: 700 points required, but 722 points sampled.
# Warning: 700 points required, but 722 points sampled.
#
# Best model at step 63000:
#   train loss: 1.55e-03
#   test loss: 1.09e-02
#   test metric: []
#
# 'train' took 520.343726 s
#
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
# Финальное lam для запуска с начальным -5: -3.3263416290283203
